# %%
import glob
import os
import numpy as np
import pandas as pd

# %%
prob_1 = glob.glob("data/captured_data/phase-1/prob-1/*.parquet")
prob_2 = glob.glob("data/captured_data/phase-1/prob-2/*.parquet")
len(prob_1), len(prob_2)
# Out:
# (118, 31)

# %%
prob_1 = glob.glob("data/captured_data/phase-1/prob-1/prob1_*")
len(prob_1)
# Out:
# 59

# %%
ref = pd.read_parquet("data/captured_data/phase-1/prob-1/prob1_0.parquet")
ref.head()
# Out:
#    feature1  feature2  feature3  feature4   feature5   feature6  feature7
# 0        -1        12     28.71     37341  34.764269 -82.233754     12085  \
# 1         7        11      4.56     48314  42.234590 -83.858655    129683
# 2       197         4     43.01     62221  32.594352 -89.977493     95666
# 3       288         9      8.73     31907  28.381704 -84.570469    173903
# 4       212         2     52.54     61071  39.724923 -89.094662     14381
#
#     feature8   feature9  feature10  feature11  feature12  feature13
# 0  34.310798 -85.949851  23.232385         23          2          6  \
# 1  41.835677 -82.599450  21.750394         15          0          6
# 2  38.438088 -89.192691  15.009756         11          1          5
# 3  33.399397 -85.824090  23.088269         17          3          5
# 4  42.227150 -90.645944  23.875300          4          0          4
#
#    feature14  feature15  feature16  is_drift  batch_id
# 0   0.925699   1.657646  64.008021         0        18
# ...

# %%
ref["feature1"].value_counts()
# Out:
# feature1
# -1      211
#  469     13
#  136     11
#  470     10
#  131     10
#        ...
#  149      1
#  298      1
#  382      1
#  433      1
#  54       1
# Name: count, Length: 235, dtype: int64

# %%
ref = pd.read_parquet("data/captured_data/phase-1/prob-1/prob1_0.parquet")
for f in prob_1:
    fileName = f.split("/")[-1]
    if fileName == "prob1_0.parquet":
        continue
    curr = pd.read_parquet(f)
    ref = pd.concat([curr, ref])
    print(f"Processing {fileName}: {len(ref)}")
# Out:
# Processing prob1_10.parquet: 2000
# Processing prob1_47.parquet: 3000
# Processing prob1_22.parquet: 4000
# Processing prob1_35.parquet: 5000
# Processing prob1_37.parquet: 6000
# Processing prob1_8.parquet: 7000
# Processing prob1_16.parquet: 8000
# Processing prob1_56.parquet: 9000
# Processing prob1_41.parquet: 10000
# Processing prob1_52.parquet: 11000
# Processing prob1_31.parquet: 12000
# Processing prob1_34.parquet: 13000
# Processing prob1_32.parquet: 14000
# Processing prob1_29.parquet: 15000
# Processing prob1_28.parquet: 16000
# Processing prob1_18.parquet: 17000
# Processing prob1_45.parquet: 18000
# Processing prob1_49.parquet: 19000
# Processing prob1_27.parquet: 20000
# Processing prob1_38.parquet: 21000
# Processing prob1_13.parquet: 22000
# Processing prob1_14.parquet: 23000
# Processing prob1_46.parquet: 24038
# Processing prob1_6.parquet: 25038
# Processing prob1_19.parquet: 26038
# Processing prob1_15.parquet: 27038
# Processing prob1_42.parquet: 28038
# ...

# %%
df = pd.read_parquet("data/captured_data/phase-1/prob-1/prob1_46.parquet")
len(df)
# Out:
# 1038

# %%
len(ref)
# Out:
# 59589

# %%
ref["feature1"].value_counts()
# Out:
# feature1
# -1      13244
#  136      664
#  212      528
#  164      485
#  470      482
#         ...
#  199        1
#  391        1
#  67         1
#  8          1
#  458        1
# Name: count, Length: 304, dtype: int64

# %%
ref["feature2"].value_counts()
# Out:
# feature2
#  2     7788
#  12    5922
#  11    5128
#  7     4806
#  0     4654
#  1     4623
#  10    3915
#  5     3821
#  9     3773
#  8     3411
#  6     3259
#  4     3193
#  3     2411
#  13    2083
# -1      802
# Name: count, dtype: int64

# %%
BASE0 = ref.copy()
BASE0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59589 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   feature1   59589 non-null  int16
#  1   feature2   59589 non-null  int8
#  2   feature3   59589 non-null  float64
#  3   feature4   59589 non-null  int64
#  4   feature5   59589 non-null  float64
#  5   feature6   59589 non-null  float64
#  6   feature7   59589 non-null  int64
#  7   feature8   59589 non-null  float64
#  8   feature9   59589 non-null  float64
#  9   feature10  59589 non-null  float64
#  10  feature11  59589 non-null  int64
#  11  feature12  59589 non-null  int64
#  12  feature13  59589 non-null  int64
#  13  feature14  59589 non-null  float64
#  14  feature15  59589 non-null  float64
#  15  feature16  59589 non-null  float64
#  16  is_drift   59589 non-null  int64
#  17  batch_id   59589 non-null  int64
# dtypes: float64(9), int16(1), int64(7), int8(1)
# memory usage: 7.9 MB

# %%
prob_1_v2 = glob.glob("data/captured_data/phase-1/prob-1/*.parquet")

# %%
i = 0

# %%
for f in prob_1_v2:
    n = f.split("/")[-1].split(".")[0]
    if not n.startswith("prob1"):
        os.rename(f, os.path.join("data/captured_data/phase-1/prob-1", f"prob12_{i}.parquet"))
        i += 1

# %%
ref = pd.read_parquet("data/captured_data/phase-1/prob-1/prob12_0.parquet")
prob_12 = glob.glob("data/captured_data/phase-1/prob-1/prob12_*")
for f in prob_12:
    fileName = f.split("/")[-1]
    if fileName == "prob12_0.parquet":
        continue
    curr = pd.read_parquet(f)
    ref = pd.concat([curr, ref])
    print(f"Processing {fileName}: {len(ref)}")
# Out:
# Processing prob12_4.parquet: 2000
# Processing prob12_15.parquet: 3000
# Processing prob12_14.parquet: 4000
# Processing prob12_51.parquet: 5000
# Processing prob12_31.parquet: 6000
# Processing prob12_34.parquet: 7000
# Processing prob12_56.parquet: 8000
# Processing prob12_23.parquet: 9000
# Processing prob12_6.parquet: 10000
# Processing prob12_3.parquet: 11000
# Processing prob12_9.parquet: 12000
# Processing prob12_10.parquet: 13000
# Processing prob12_29.parquet: 14000
# Processing prob12_36.parquet: 15000
# Processing prob12_1.parquet: 16000
# Processing prob12_7.parquet: 17000
# Processing prob12_46.parquet: 18000
# Processing prob12_5.parquet: 19000
# Processing prob12_39.parquet: 20000
# Processing prob12_37.parquet: 21000
# Processing prob12_18.parquet: 22000
# Processing prob12_25.parquet: 23000
# Processing prob12_19.parquet: 24000
# Processing prob12_22.parquet: 25000
# Processing prob12_33.parquet: 26000
# Processing prob12_11.parquet: 27000
# ...

# %%
ref[ref["batch_id"] == 26]
# Out:
#      feature1  feature2  feature3  feature4   feature5    feature6  feature7
# 0         382         7     15.97     93723  34.365997 -122.028918    570271  \
# 1          -1         2     16.47     89801  40.718894 -117.514280     23298
# 2          73         7     47.45     80537  38.124850 -106.605618     82751
# 3         480         3     71.06     76132  31.659100  -97.304834    813980
# 4         453         3     47.92      8260  33.481884  -76.559697     13661
# ..        ...       ...       ...       ...        ...         ...       ...
# 995       119         2     62.74     38637  32.149311  -90.059520     26066
# 996       225        10      2.41     18901  39.302905  -74.751431     48571
# 997        73         4     58.33     48380  43.072240  -87.321190     20009
# 998        -1         1    111.49     84098  41.679630 -108.900424     24878
# 999       212         1      6.14     80513  36.857325 -109.488524     10296
#
# ...

# %%
BASE0[BASE0["batch_id"] == 5].equals(ref[ref["batch_id"] == 5])
# Out:
# True
